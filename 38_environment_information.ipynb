# %% [markdown]
# # ENVIRONMENT INFORMATION

# %% [markdown]
# ## OS Details

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 20.10
# Release:	20.10
# Codename:	groovy

# %% [markdown]
# ## GPU Details

# %%
# !nvidia-smi
# Out:
# Wed Aug  4 14:08:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.80       Driver Version: 460.80       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 960     Off  | 00000000:0A:00.0  On |                  N/A |
# |  0%   50C    P0    38W / 130W |    581MiB /  4010MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %% [markdown]
# ## Conda Environment
# The base conda environment provided for the course required some upgrades to function correctly on the hardware and OS. <br/>
# __NOTE:__ An environment resourses file can be found in the appendix directory.

# %%
# !conda list
# Out:
# # packages in environment at /home/user/anaconda3/envs/exts-ml:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                       1_gnu
# _tflow_select             2.1.0                       gpu    anaconda
# absl-py                   0.11.0           py36h5fab9bb_0    conda-forge
# acrylic                   0.2.2                    pypi_0    pypi
# aiohttp                   3.7.4.post0              pypi_0    pypi
# aiohttp-cors              0.7.0                    pypi_0    pypi
# aioredis                  1.3.1                    pypi_0    pypi
# arrow                     0.15.7                   pypi_0    pypi
# astor                     0.8.1              pyh9f0ad1d_0    conda-forge
# async-timeout             3.0.1                    pypi_0    pypi
# async_generator           1.10             py36h28b3542_0
# ...
