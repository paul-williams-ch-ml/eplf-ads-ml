# %% [markdown]
# # Hyperparameters for Logistic Regression Classifier

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# The standard <code>read_data()</code> function seen throughout the project. designed to simplify and standardize the data reading process. <br/>In addition the _Global_ variables associated with its function are defined along with the relitive paths to the data files.<br/>__NOTE:__ in a business environment this function would be placed into a pythin module and imported. Here it is included into the notebook to provide full transparency.

# %%
# required modules
import numpy as np
import pandas as pd
import sqlite3
from sklearn import preprocessing
import colorsys

# groups
COLOURS      = 10
PALETTES     = 11
LRG_PALETTES = 12
IMAGE        = 13
TILES        = 14

# sets
TRAIN        = 20
TEST         = 21
VALIDATE     = 22

# targets
ARTIST       = 30
GENRE        = 31
STYLE        = 32

# array
DATA         = 40
CATAGORY     = 41
CATAGORY_NUM = 42
IMAGE_TAG    = 43
TILE_INDEX   = 44

# colour systems
HLS          = 50
RGB          = 51
RAW          = 52

# an overly complicated method of defining the data file path
data_file  = {COLOURS      : {TRAIN    : {ARTIST : "./data/colour_sets/artist_train_colours.npz",
                                          GENRE  : "./data/colour_sets/genre_train_colours.npz",
                                          STYLE  : "./data/colour_sets/style_train_colours.npz"},
                              TEST     : {ARTIST : "./data/colour_sets/artist_test_colours.npz",
                                          GENRE  : "./data/colour_sets/genre_test_colours.npz",
                                          STYLE  : "./data/colour_sets/style_test_colours.npz"} ,
                              VALIDATE : {ARTIST : "./data/colour_sets/artist_validation_colours.npz",
                                          GENRE  : "./data/colour_sets/genre_validation_colours.npz",
                                          STYLE  : "./data/colour_sets/style_validation_colours.npz"}},
              PALETTES     : {TRAIN    : {ARTIST : "./data/palette_sets/artist_train_palettes.npz",
                                          GENRE  : "./data/palette_sets/genre_train_palettes.npz",
                                          STYLE  : "./data/palette_sets/style_train_palettes.npz"} ,
                              TEST     : {ARTIST : "./data/palette_sets/artist_test_palettes.npz",
                                          GENRE  : "./data/palette_sets/genre_test_palettes.npz",
                                          STYLE  : "./data/palette_sets/style_test_palettes.npz"} ,
                              VALIDATE : {ARTIST : "./data/palette_sets/artist_validation_palettes.npz",
                                          GENRE  : "./data/palette_sets/genre_validation_palettes.npz",
                                          STYLE  : "./data/palette_sets/style_validation_palettes.npz"}},
              LRG_PALETTES : {TRAIN    : {ARTIST : "./data/large_palette_sets/artist_train_palettes.npz",
                                          GENRE  : "./data/large_palette_sets/genre_train_palettes.npz",
                                          STYLE  : "./data/large_palette_sets/style_train_palettes.npz"} ,
                              TEST     : {ARTIST : "./data/large_palette_sets/artist_test_palettes.npz",
                                          GENRE  : "./data/large_palette_sets/genre_test_palettes.npz",
                                          STYLE  : "./data/large_palette_sets/style_test_palettes.npz"} ,
                              VALIDATE : {ARTIST : "./data/large_palette_sets/artist_validation_palettes.npz",
                                          GENRE  : "./data/large_palette_sets/genre_validation_palettes.npz",
                                          STYLE  : "./data/large_palette_sets/style_validation_palettes.npz"}},
              IMAGE        : {TRAIN    : {ARTIST : "./data/full_image_feature_sets/artist_train_features.npz",
                                          GENRE  : "./data/full_image_feature_sets/genre_train_features.npz",
                                          STYLE  : "./data/full_image_feature_sets/style_train_features.npz"} ,
                              TEST     : {ARTIST : "./data/full_image_feature_sets/artist_test_features.npz",
                                          GENRE  : "./data/full_image_feature_sets/genre_test_features.npz",
                                          STYLE  : "./data/full_image_feature_sets/style_test_features.npz"} ,
                              VALIDATE : {ARTIST : "./data/full_image_feature_sets/artist_validation_features.npz",
                                          GENRE  : "./data/full_image_feature_sets/genre_validation_features.npz",
                                          STYLE  : "./data/full_image_feature_sets/style_validation_features.npz"}},
              TILES        : {TRAIN    : {ARTIST : "./data/feature_sets/artist_train_features.npz",
                                          GENRE  : "./data/feature_sets/genre_train_features.npz",
                                          STYLE  : "./data/feature_sets/style_train_features.npz"} ,
                              TEST     : {ARTIST : "./data/feature_sets/artist_test_features.npz",
                                          GENRE  : "./data/feature_sets/genre_test_features.npz",
                                          STYLE  : "./data/feature_sets/style_test_features.npz"} ,
                              VALIDATE : {ARTIST : "./data/feature_sets/artist_validation_features.npz",
                                          GENRE  : "./data/feature_sets/genre_validation_features.npz",
                                          STYLE  : "./data/feature_sets/style_validation_features.npz"}}}

# Create a DB connection between python and the file system
conn = sqlite3.connect("./data/database/artist.db")

# the fuction that provides a standard data read method
def read_data(data_group, data_set, data_target, data_type, colour_system = RGB):
    
    # read the data file
    data = np.load(data_file[data_group][data_set][data_target], allow_pickle=True)

    # if tile index is requested
    if   data_type    == TILE_INDEX:
        # when group is tiles, return the tile indexes
        if data_group == TILES:
            return pd.DataFrame(data["arr_3"], columns = {"tile_index"})
        # otherwise, just return an emtpy dataset
        else:
            return pd.DataFrame(columns = {"tile_index"})
    # if image tags are requested
    elif data_type == IMAGE_TAG:
        return pd.DataFrame(data["arr_2"], columns = {"image_tag"})
    # if catagory data is requested
    elif data_type == CATAGORY:
        return pd.DataFrame(data["arr_1"], columns = {"catagory"})
    # if catagory_num is requested
    elif data_type == CATAGORY_NUM:
        # select data for the appropriate lookup table
        if   data_target == ARTIST: 
            query_string = "SELECT ID, NAME  AS VALUE FROM ARTIST"
        elif data_target == GENRE:
            query_string = "SELECT ID, GENRE AS VALUE FROM GENRE"
        else:
            query_string = "SELECT ID, STYLE AS VALUE FROM STYLE" 
        # build the lookup table
        lookup = pd.read_sql_query(query_string, conn)
        # get the catagory data
        data   = pd.DataFrame(data["arr_1"], columns = {"catagory"})
        # convert the catagory text labels to numeric catagory ids
        return pd.DataFrame(data["catagory"].apply(lambda x: lookup[lookup["VALUE"] == x]["id"].values[0]))
    # data requested
    elif data_group == COLOURS:
        # reshape the data and normalize
        return pd.DataFrame(preprocessing.normalize(data["arr_0"].reshape(data["arr_0"].shape[0],data["arr_0"].shape[1] * data["arr_0"].shape[2])))
    elif data_group == PALETTES or data_group == LRG_PALETTES:

        # extract the colour data
        colour_data = data["arr_0"]
        
        # find the datas dimensions
        records, _, palette_length, palette_layers = np.shape(colour_data)
        
        # reshape
        colour_data = colour_data.reshape(records * palette_length, palette_layers)
        
        # convert to a dataframe
        colour_data_df = pd.DataFrame(colour_data, columns =["r","g","b"])
        
        # process the data with different colour systems
        
        # hue, luminance, saturation
        if colour_system == HLS:
            
            # define a dataframe to hold the hls values
            hls_data_df = pd.DataFrame(columns =["h","l","s"])

            # loop through each record
            for row in colour_data_df.iterrows():
                
                # extract the r,g,b values and devide them by 255 ready to convert
                r, g, b = row[1].values/255

                # convert the values and add them to the dataframe
                hls_data_df.loc[len(hls_data_df)] = colorsys.rgb_to_hls(r, g, b)
            
            # create datasets and normalize
            hue        = pd.DataFrame(preprocessing.normalize(np.array(hls_data_df["h"]).reshape(records, palette_length)))
            luminance  = pd.DataFrame(preprocessing.normalize(np.array(hls_data_df["l"]).reshape(records, palette_length)))
            saturation = pd.DataFrame(preprocessing.normalize(np.array(hls_data_df["s"]).reshape(records, palette_length)))  
            
            # return values
            return hue, luminance, saturation
            
        # red, green, blue unnormalized
        elif colour_system == RAW:
            red   = pd.DataFrame(np.array(colour_data_df["r"]).reshape(records, palette_length))
            green = pd.DataFrame(np.array(colour_data_df["g"]).reshape(records, palette_length))
            blue  = pd.DataFrame(np.array(colour_data_df["b"]).reshape(records, palette_length))
            
            # return values
            return red, green, blue            
            
        # red, green, blue normalized- (default)
        else:
    
            # create datasets and normalize
            red   = pd.DataFrame(preprocessing.normalize(np.array(colour_data_df["r"]).reshape(records, palette_length)))
            green = pd.DataFrame(preprocessing.normalize(np.array(colour_data_df["g"]).reshape(records, palette_length)))
            blue  = pd.DataFrame(preprocessing.normalize(np.array(colour_data_df["b"]).reshape(records, palette_length)))
            
            # return values
            return red, green, blue

    elif data_group == IMAGE:
        # reshape the data and normalize
        return pd.DataFrame(preprocessing.normalize(data["arr_0"].reshape(data["arr_0"].shape[0],data["arr_0"].shape[2])))
    else:
        # normalize the data
        return pd.DataFrame(preprocessing.normalize(data["arr_0"]))

# %% [markdown]
# The <code>get_colours()</code> function provides a list of colours the length of the value <code>no_of_colours</code>. This can be useful for consisten colours when used across multiple plots.

# %%
# required modules
import random

# define colours used 
def get_colours(no_of_colours):
    
    # consistent randomness
    random.seed(42)
    
    # colour list
    colours = []

    # generate colours
    for i in range(no_of_colours):
        colours.append('#%06X' % random.randint(0, 0xFFFFFF))
    
    # return the colour list
    return colours

# %% [markdown]
# Generate sorted lists of _Artists, Genres_ & _Styles_. These are used in a variety of situations. These functions ensure that the lists are always defined in the same order.

# %%
# define data lists
artists = list(set(read_data(COLOURS, TRAIN, ARTIST, CATAGORY)["catagory"]))
styles  = list(set(read_data(COLOURS, TRAIN, STYLE,  CATAGORY)["catagory"]))
genres  = list(set(read_data(COLOURS, TRAIN, GENRE,  CATAGORY)["catagory"]))

# sort the lists
artists.sort()
styles.sort()
genres.sort()

# %% [markdown]
# Function <code>find_best_hyperparameters()</code> uses a _Grid Search_ to loop thought the hyperparameter values. All combinations are displayed with their score. The combination that achieves the best score is highlighted and returned.

# %%
def find_best_hyperparameters(X_train, y_train, group, target, results):

    # define models and parameters
    model = LogisticRegression()
    

    # define grid search
    grid        = dict(solver      = ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
                       penalty     = ["l1", "l2"],
                       C           = [0.1, 1.0, 10.0, 100.0],
                       multi_class = ["ovr", "multinomial"])
    
    cv          = RepeatedStratifiedKFold(n_splits     = 5, 
                                          n_repeats    = 2, 
                                          random_state = 42)
    
    grid_search = GridSearchCV(estimator   = model, 
                               param_grid  = grid, 
                               n_jobs      = -1, 
                               cv          = cv, 
                               scoring     = "accuracy",
                               error_score = 0)
    
    grid_result = grid_search.fit(X_train, y_train)
    
    # results
    results = results.append({"classifier" : "LogisticRegression",
                              "group"      : group,
                              "target"     : target,
                              "score"      : round(grid_result.best_score_, 6),
                              "params"     : grid_result.best_params_},
                              ignore_index = True)
    
    print("-" * 90, "\nBest score: {} using parametrs: {}".format(round(grid_result.best_score_, 6), grid_result.best_params_))
    print("-" * 90)

    means  = grid_result.cv_results_["mean_test_score"]
    stds   = grid_result.cv_results_["std_test_score" ]
    params = grid_result.cv_results_["params"         ]
    
    for mean, stdev, param in zip(means, stds, params):
        print("Mean: {} StdDev: {} using: {}".format(round(mean, 6), round(stdev, 6), param))
        
    print("-" * 90, "\n")
    
    
    return results

# %% [markdown]
# ## Apply Various Hyperparameters to the Different Data Groups and Target Catagories to Find Those That Perform Best
# As the best results are returned. they are added to the <code>results</code> DataFrame.

# %%
# dataframe to hold the best results
results = pd.DataFrame()

# %%
results = find_best_hyperparameters(read_data(COLOURS,  TRAIN, ARTIST, DATA), read_data(COLOURS, TRAIN, ARTIST, CATAGORY), "COLOURS", "ARTIST", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.514693 using parametrs: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.394771 StdDev: 0.005234 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.394339 StdDev: 0.004974 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.412489 StdDev: 0.006255 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.412489 StdDev: 0.006255 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.414866 StdDev: 0.006004 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.412489 StdDev: 0.006255 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.412489 StdDev: 0.006255 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.396716 StdDev: 0.005141 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.427831 StdDev: 0.005986 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.427831 StdDev: 0.005986 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.427831 StdDev: 0.005986 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.427831 StdDev: 0.005986 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.466724 StdDev: 0.013925 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.468237 StdDev: 0.013862 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.474071 StdDev: 0.011829 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.474071 StdDev: 0.011829 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.472126 StdDev: 0.013459 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.474071 StdDev: 0.011829 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.474071 StdDev: 0.011829 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.468669 StdDev: 0.014656 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.48898 StdDev: 0.018493 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.489196 StdDev: 0.018319 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.48898 StdDev: 0.018493 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.48898 StdDev: 0.018493 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.510156 StdDev: 0.023822 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.513181 StdDev: 0.020668 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.511668 StdDev: 0.014597 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.511452 StdDev: 0.014719 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.51102 StdDev: 0.013777 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.511668 StdDev: 0.014597 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.511668 StdDev: 0.014597 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.513613 StdDev: 0.024662 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.514693 StdDev: 0.024729 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.513397 StdDev: 0.024375 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.514693 StdDev: 0.024729 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.514693 StdDev: 0.024729 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.434961 StdDev: 0.010156 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.490061 StdDev: 0.01853 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.500432 StdDev: 0.016653 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.501945 StdDev: 0.017814 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.50108 StdDev: 0.016697 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.500432 StdDev: 0.017411 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.504538 StdDev: 0.019587 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.477528 StdDev: 0.021705 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.496327 StdDev: 0.020611 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.496327 StdDev: 0.018667 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.498487 StdDev: 0.022221 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.499136 StdDev: 0.023289 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
results = find_best_hyperparameters(read_data(COLOURS,  TRAIN, GENRE,  DATA), read_data(COLOURS, TRAIN, GENRE,  CATAGORY), "COLOURS", "GENRE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.303587 using parametrs: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.229473 StdDev: 0.01033 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.232282 StdDev: 0.011407 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.280683 StdDev: 0.013441 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.280683 StdDev: 0.013441 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.277874 StdDev: 0.01262 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.280683 StdDev: 0.013441 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.280683 StdDev: 0.013441 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.232066 StdDev: 0.011149 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.281115 StdDev: 0.014816 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.281115 StdDev: 0.014816 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.281331 StdDev: 0.014798 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.281115 StdDev: 0.014816 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.281763 StdDev: 0.016171 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.280899 StdDev: 0.015539 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.296024 StdDev: 0.008681 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.296024 StdDev: 0.008681 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.294728 StdDev: 0.007983 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.29624 StdDev: 0.008777 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.296024 StdDev: 0.008681 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.279386 StdDev: 0.017695 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.299481 StdDev: 0.010728 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.299481 StdDev: 0.010728 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.299265 StdDev: 0.010794 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.299481 StdDev: 0.010728 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.29019 StdDev: 0.012753 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.293647 StdDev: 0.015932 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.303587 StdDev: 0.00895 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.303155 StdDev: 0.009022 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.302723 StdDev: 0.008828 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.303587 StdDev: 0.00895 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.303587 StdDev: 0.00895 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.290622 StdDev: 0.014991 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.297969 StdDev: 0.009425 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.298833 StdDev: 0.012089 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.297969 StdDev: 0.009425 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.297753 StdDev: 0.009793 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.224719 StdDev: 0.016929 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.268366 StdDev: 0.013717 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.284572 StdDev: 0.013572 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.283276 StdDev: 0.014558 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.284356 StdDev: 0.013054 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.288462 StdDev: 0.011168 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.289974 StdDev: 0.010509 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.257995 StdDev: 0.013978 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.276577 StdDev: 0.012415 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.272688 StdDev: 0.013164 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.277226 StdDev: 0.012837 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.283276 StdDev: 0.011862 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
results = find_best_hyperparameters(read_data(COLOURS,  TRAIN, STYLE,  DATA), read_data(COLOURS, TRAIN, STYLE, CATAGORY), "COLOURS", "STYLE",  results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.304798 using parametrs: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.126488 StdDev: 0.011213 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.129367 StdDev: 0.012261 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.26929 StdDev: 0.013919 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.26929 StdDev: 0.013919 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.266027 StdDev: 0.013477 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.269098 StdDev: 0.013793 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.26929 StdDev: 0.013919 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.125336 StdDev: 0.01083 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.269866 StdDev: 0.012428 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.270058 StdDev: 0.012453 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.269866 StdDev: 0.012428 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.269866 StdDev: 0.012428 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.281574 StdDev: 0.016929 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.281382 StdDev: 0.016501 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.297121 StdDev: 0.009702 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.297121 StdDev: 0.009702 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.298081 StdDev: 0.009125 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.297121 StdDev: 0.009702 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.297121 StdDev: 0.009702 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.278503 StdDev: 0.019667 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.300576 StdDev: 0.008727 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.300576 StdDev: 0.008727 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.300576 StdDev: 0.008727 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.300576 StdDev: 0.008727 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.293858 StdDev: 0.016146 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.299616 StdDev: 0.013803 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.304415 StdDev: 0.012006 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.304607 StdDev: 0.012138 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.303839 StdDev: 0.012621 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.304223 StdDev: 0.011876 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.304223 StdDev: 0.011916 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.292131 StdDev: 0.014744 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.304031 StdDev: 0.011916 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.304798 StdDev: 0.011298 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.304031 StdDev: 0.011916 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.303839 StdDev: 0.01196 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.207678 StdDev: 0.010774 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.25048 StdDev: 0.018966 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.269674 StdDev: 0.020062 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.269674 StdDev: 0.019012 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.269482 StdDev: 0.019906 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.270825 StdDev: 0.021095 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.274472 StdDev: 0.016554 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.240883 StdDev: 0.017491 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.258733 StdDev: 0.015445 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.258541 StdDev: 0.013502 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.260461 StdDev: 0.014521 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.264107 StdDev: 0.014531 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the red, green and blue layers
l, r, f = np.shape(                            read_data(PALETTES, TRAIN, ARTIST, DATA, RGB))
results = find_best_hyperparameters(np.reshape(read_data(PALETTES, TRAIN, ARTIST, DATA, RGB), (r, l * f)), read_data(PALETTES, TRAIN, ARTIST, CATAGORY), "PALETTES-RGB", "ARTIST", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.372083 using parametrs: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.357174 StdDev: 0.004541 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.359551 StdDev: 0.003326 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.359551 StdDev: 0.004016 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.359551 StdDev: 0.004016 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.356093 StdDev: 0.003919 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.359551 StdDev: 0.004016 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.359551 StdDev: 0.004016 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.358902 StdDev: 0.005479 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.360631 StdDev: 0.004407 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.360847 StdDev: 0.004339 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.360631 StdDev: 0.004407 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.360631 StdDev: 0.004407 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.357822 StdDev: 0.012003 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.355877 StdDev: 0.010415 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.363656 StdDev: 0.008246 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.36344 StdDev: 0.008511 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.358254 StdDev: 0.006406 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.363656 StdDev: 0.008246 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.362792 StdDev: 0.007147 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.366681 StdDev: 0.014712 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.365601 StdDev: 0.0103 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.356093 StdDev: 0.00999 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.365601 StdDev: 0.0103 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.364952 StdDev: 0.01042 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.351556 StdDev: 0.016881 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.350475 StdDev: 0.013073 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.358254 StdDev: 0.012092 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.358038 StdDev: 0.01283 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.3535 StdDev: 0.011394 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.355445 StdDev: 0.01195 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.355229 StdDev: 0.011496 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.367113 StdDev: 0.014996 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.372083 StdDev: 0.017865 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.355013 StdDev: 0.012474 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.368626 StdDev: 0.012423 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.36841 StdDev: 0.01284 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the red, green and blue layers
l, r, f = np.shape(                            read_data(PALETTES, TRAIN, GENRE, DATA, RGB))
results = find_best_hyperparameters(np.reshape(read_data(PALETTES, TRAIN, GENRE, DATA, RGB), (r, l * f)), read_data(PALETTES, TRAIN, GENRE, CATAGORY), "PALETTES-RGB", "GENRE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.213483 using parametrs: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.213483 StdDev: 0.002806 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.213051 StdDev: 0.002885 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.210026 StdDev: 0.015808 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.210026 StdDev: 0.015808 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.211106 StdDev: 0.015903 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.20981 StdDev: 0.01571 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.210026 StdDev: 0.015808 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.212835 StdDev: 0.003177 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.209594 StdDev: 0.014784 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.209378 StdDev: 0.014786 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.209594 StdDev: 0.014784 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.209594 StdDev: 0.014784 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.204408 StdDev: 0.010575 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.20376 StdDev: 0.014071 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.211322 StdDev: 0.01316 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.211322 StdDev: 0.01316 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.20981 StdDev: 0.011168 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.211106 StdDev: 0.013051 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.211322 StdDev: 0.01316 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.203544 StdDev: 0.0147 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.212619 StdDev: 0.011621 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.213483 StdDev: 0.011614 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.212619 StdDev: 0.011621 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.212619 StdDev: 0.011621 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.208946 StdDev: 0.009246 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.207217 StdDev: 0.01025 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.212187 StdDev: 0.012339 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.212187 StdDev: 0.012339 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.212403 StdDev: 0.011616 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.212187 StdDev: 0.012339 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.212403 StdDev: 0.012295 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.20484 StdDev: 0.013391 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.213051 StdDev: 0.012058 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.210026 StdDev: 0.01436 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.213051 StdDev: 0.012058 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.213267 StdDev: 0.012028 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.192956 StdDev: 0.012711 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.200951 StdDev: 0.010802 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.204408 StdDev: 0.011204 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.204624 StdDev: 0.011333 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.20484 StdDev: 0.00944 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.205272 StdDev: 0.010283 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.205704 StdDev: 0.009412 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.193388 StdDev: 0.013729 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.196413 StdDev: 0.012801 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.200086 StdDev: 0.016936 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.19771 StdDev: 0.012888 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.199654 StdDev: 0.013198 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the red, green and blue layers
l, r, f = np.shape(                            read_data(PALETTES, TRAIN, STYLE, DATA, RGB))
results = find_best_hyperparameters(np.reshape(read_data(PALETTES, TRAIN, STYLE, DATA, RGB), (r, l * f)), read_data(PALETTES, TRAIN, STYLE, CATAGORY), "PALETTES-RGB", "STYLE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.186948 using parametrs: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.140883 StdDev: 0.001247 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.141267 StdDev: 0.0011 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.156622 StdDev: 0.007563 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.156622 StdDev: 0.007563 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.153551 StdDev: 0.007183 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.156622 StdDev: 0.007563 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.156622 StdDev: 0.007563 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.141267 StdDev: 0.0011 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.157006 StdDev: 0.006022 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.157006 StdDev: 0.006022 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.157006 StdDev: 0.006022 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.157006 StdDev: 0.006022 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.170058 StdDev: 0.009609 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.173321 StdDev: 0.010341 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.17524 StdDev: 0.008206 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.17524 StdDev: 0.008206 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.169866 StdDev: 0.009325 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.175432 StdDev: 0.00864 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.17524 StdDev: 0.008206 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.174664 StdDev: 0.009991 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.178695 StdDev: 0.008473 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.179846 StdDev: 0.00842 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.178695 StdDev: 0.008473 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.178695 StdDev: 0.008473 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.179271 StdDev: 0.015202 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.179463 StdDev: 0.016187 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.186948 StdDev: 0.01457 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.186948 StdDev: 0.01457 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.182917 StdDev: 0.012178 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.186948 StdDev: 0.01457 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.185988 StdDev: 0.014528 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.179271 StdDev: 0.014711 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.186948 StdDev: 0.014689 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.182342 StdDev: 0.013529 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.186756 StdDev: 0.014545 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.186372 StdDev: 0.014741 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.170633 StdDev: 0.013473 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.17524 StdDev: 0.012544 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.177927 StdDev: 0.014178 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.177159 StdDev: 0.013135 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.176967 StdDev: 0.013571 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.177543 StdDev: 0.014018 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.179271 StdDev: 0.014137 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.168522 StdDev: 0.012994 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.173704 StdDev: 0.016021 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.171593 StdDev: 0.01737 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.173129 StdDev: 0.015265 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.175048 StdDev: 0.013269 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the hue, luminence and saturation layers
l, r, f = np.shape(                            read_data(PALETTES, TRAIN, ARTIST, DATA, HLS))
results = find_best_hyperparameters(np.reshape(read_data(PALETTES, TRAIN, ARTIST, DATA, HLS), (r, l * f)), read_data(PALETTES, TRAIN, ARTIST, CATAGORY), "PALETTES-HLS", "ARTIST", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.399957 using parametrs: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.366249 StdDev: 0.010855 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.365385 StdDev: 0.011402 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.378997 StdDev: 0.013956 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.378997 StdDev: 0.013956 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.377269 StdDev: 0.012961 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.378997 StdDev: 0.013956 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.378997 StdDev: 0.013956 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.368626 StdDev: 0.008742 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.385048 StdDev: 0.013659 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.385048 StdDev: 0.013659 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.385048 StdDev: 0.013659 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.385048 StdDev: 0.013659 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.388073 StdDev: 0.011847 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.387424 StdDev: 0.010992 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.384831 StdDev: 0.013353 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.384831 StdDev: 0.013353 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.384183 StdDev: 0.014374 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.384831 StdDev: 0.013353 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.385048 StdDev: 0.013226 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.399957 StdDev: 0.018305 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.397364 StdDev: 0.016941 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.397364 StdDev: 0.016848 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.397364 StdDev: 0.016941 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.39758 StdDev: 0.0169 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.372515 StdDev: 0.011093 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.372515 StdDev: 0.010422 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.378781 StdDev: 0.011455 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.378781 StdDev: 0.011455 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.378781 StdDev: 0.01051 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.378781 StdDev: 0.011455 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.379213 StdDev: 0.010942 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.391098 StdDev: 0.022451 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.39866 StdDev: 0.019301 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.39758 StdDev: 0.015182 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.398228 StdDev: 0.019702 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.398012 StdDev: 0.019104 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.365817 StdDev: 0.013137 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.367329 StdDev: 0.010343 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.36841 StdDev: 0.012066 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.36841 StdDev: 0.012066 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.37057 StdDev: 0.010022 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.368194 StdDev: 0.010998 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.371867 StdDev: 0.011744 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.385264 StdDev: 0.018437 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.389801 StdDev: 0.020523 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.384615 StdDev: 0.018737 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.388505 StdDev: 0.019112 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.389585 StdDev: 0.01799 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the hue, luminence and saturation layers
l, r, f = np.shape(                            read_data(PALETTES, TRAIN, GENRE, DATA, HLS))
results = find_best_hyperparameters(np.reshape(read_data(PALETTES, TRAIN, GENRE, DATA, HLS), (r, l * f)), read_data(PALETTES, TRAIN, GENRE, CATAGORY), "PALETTES-HLS", "GENRE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.229473 using parametrs: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.226448 StdDev: 0.010953 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.228176 StdDev: 0.013006 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.22688 StdDev: 0.016126 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.22688 StdDev: 0.016126 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.227744 StdDev: 0.015879 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.22688 StdDev: 0.016126 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.22688 StdDev: 0.016126 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.229473 StdDev: 0.013698 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.226448 StdDev: 0.015357 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.226448 StdDev: 0.015843 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.226448 StdDev: 0.015357 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.226448 StdDev: 0.015843 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.226664 StdDev: 0.014029 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.226232 StdDev: 0.014561 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.225367 StdDev: 0.014975 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.225367 StdDev: 0.014975 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.224719 StdDev: 0.014688 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.225367 StdDev: 0.014975 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.225367 StdDev: 0.014975 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.22688 StdDev: 0.014724 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.221262 StdDev: 0.014401 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.22191 StdDev: 0.013565 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.221262 StdDev: 0.014401 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.221262 StdDev: 0.014401 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.207217 StdDev: 0.010152 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.207433 StdDev: 0.009976 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.212835 StdDev: 0.008597 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.213051 StdDev: 0.008612 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.213267 StdDev: 0.008851 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.212835 StdDev: 0.008597 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.212835 StdDev: 0.008597 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.201383 StdDev: 0.012178 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.210026 StdDev: 0.009802 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.207865 StdDev: 0.012495 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.210026 StdDev: 0.009802 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.210026 StdDev: 0.009802 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.191443 StdDev: 0.01325 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.197277 StdDev: 0.013417 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.200086 StdDev: 0.011519 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.200086 StdDev: 0.011519 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.201815 StdDev: 0.01348 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.200951 StdDev: 0.013196 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.204192 StdDev: 0.012527 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.188202 StdDev: 0.009102 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.189931 StdDev: 0.010243 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.195981 StdDev: 0.014586 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.190795 StdDev: 0.010175 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.19274 StdDev: 0.012388 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the hue, luminence and saturation layers
l, r, f = np.shape(                            read_data(PALETTES, TRAIN, STYLE, DATA, HLS))
results = find_best_hyperparameters(np.reshape(read_data(PALETTES, TRAIN, STYLE, DATA, HLS), (r, l * f)), read_data(PALETTES,   TRAIN, STYLE,  CATAGORY), "PALETTES-HLS", "STYLE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.227447 using parametrs: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.21094 StdDev: 0.005332 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.213244 StdDev: 0.006525 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.226871 StdDev: 0.009747 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.226871 StdDev: 0.009747 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.225336 StdDev: 0.009665 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.226871 StdDev: 0.009747 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.226871 StdDev: 0.009747 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.215355 StdDev: 0.006771 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.226488 StdDev: 0.010797 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.226679 StdDev: 0.011263 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.226488 StdDev: 0.010797 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.226488 StdDev: 0.010797 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.226679 StdDev: 0.010355 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.227447 StdDev: 0.011394 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.221689 StdDev: 0.009754 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.221689 StdDev: 0.009754 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.221689 StdDev: 0.009675 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.221689 StdDev: 0.009754 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.221689 StdDev: 0.009754 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.227255 StdDev: 0.00678 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.222073 StdDev: 0.008595 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.222073 StdDev: 0.008949 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.222073 StdDev: 0.008595 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.222073 StdDev: 0.008595 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.211132 StdDev: 0.008391 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.212476 StdDev: 0.008772 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.214012 StdDev: 0.008902 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.214012 StdDev: 0.008902 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.21286 StdDev: 0.009174 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.214012 StdDev: 0.008902 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.214012 StdDev: 0.008902 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.21094 StdDev: 0.008829 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.213244 StdDev: 0.007078 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.21286 StdDev: 0.006996 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.213244 StdDev: 0.007078 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.213244 StdDev: 0.007078 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.202303 StdDev: 0.012015 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.20595 StdDev: 0.012588 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.208253 StdDev: 0.012099 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.208253 StdDev: 0.012099 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.208061 StdDev: 0.011234 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.208253 StdDev: 0.011878 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.209405 StdDev: 0.012031 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.203455 StdDev: 0.010438 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.205182 StdDev: 0.010664 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.206334 StdDev: 0.007959 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.204607 StdDev: 0.009899 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.206334 StdDev: 0.009717 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the red, green and blue layers
l, r, f = np.shape(                            read_data(LRG_PALETTES, TRAIN, ARTIST, DATA, RGB))
results = find_best_hyperparameters(np.reshape(read_data(LRG_PALETTES, TRAIN, ARTIST, DATA, RGB), (r, l * f)), read_data(LRG_PALETTES, TRAIN, ARTIST, CATAGORY), "LRG-PALETTES-RGB", "ARTIST", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.359551 using parametrs: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.357606 StdDev: 0.006128 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.357606 StdDev: 0.00693 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.355661 StdDev: 0.005638 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.355661 StdDev: 0.005638 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.354149 StdDev: 0.003868 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.355661 StdDev: 0.005638 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.355661 StdDev: 0.005638 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.35739 StdDev: 0.009964 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.357174 StdDev: 0.005478 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.357606 StdDev: 0.005308 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.357174 StdDev: 0.005478 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.357174 StdDev: 0.005478 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.314823 StdDev: 0.018127 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.322169 StdDev: 0.016346 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.352852 StdDev: 0.011871 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.352204 StdDev: 0.011836 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.347234 StdDev: 0.013504 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.352636 StdDev: 0.011765 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.351772 StdDev: 0.011342 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.328003 StdDev: 0.014345 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.359551 StdDev: 0.016068 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.35134 StdDev: 0.014814 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.359334 StdDev: 0.016382 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.356742 StdDev: 0.017439 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.272688 StdDev: 0.020589 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.301642 StdDev: 0.014446 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.315255 StdDev: 0.014822 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.317416 StdDev: 0.015194 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.309421 StdDev: 0.017039 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.317632 StdDev: 0.016569 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.318712 StdDev: 0.017859 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.314175 StdDev: 0.017005 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.328652 StdDev: 0.011099 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.324114 StdDev: 0.016673 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.326707 StdDev: 0.012349 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.331893 StdDev: 0.016459 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the red, green and blue layers
l, r, f = np.shape(                            read_data(LRG_PALETTES, TRAIN, GENRE, DATA, RGB))
results = find_best_hyperparameters(np.reshape(read_data(LRG_PALETTES, TRAIN, GENRE, DATA, RGB), (r, l * f)), read_data(LRG_PALETTES, TRAIN, GENRE, CATAGORY), "LRG-PALETTES-RGB", "GENRE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.22299 using parametrs: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.213483 StdDev: 0.002806 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.211538 StdDev: 0.003197 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.221046 StdDev: 0.01475 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.22083 StdDev: 0.014916 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.222342 StdDev: 0.014164 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.221046 StdDev: 0.01475 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.221262 StdDev: 0.014764 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.213267 StdDev: 0.003176 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.220614 StdDev: 0.01475 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.220614 StdDev: 0.015012 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.220614 StdDev: 0.01475 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.220614 StdDev: 0.01475 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.218021 StdDev: 0.013551 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.22299 StdDev: 0.0134 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.219317 StdDev: 0.011575 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.219101 StdDev: 0.011837 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.218453 StdDev: 0.01025 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.219317 StdDev: 0.011575 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.219317 StdDev: 0.011575 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.22083 StdDev: 0.015715 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.218021 StdDev: 0.013845 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.218021 StdDev: 0.013476 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.218021 StdDev: 0.013448 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.218021 StdDev: 0.013845 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.206137 StdDev: 0.007616 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.209162 StdDev: 0.009807 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.216292 StdDev: 0.012632 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.216508 StdDev: 0.012629 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.217156 StdDev: 0.013162 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.216292 StdDev: 0.012632 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.216292 StdDev: 0.012632 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.200303 StdDev: 0.012949 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.215212 StdDev: 0.012319 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.216076 StdDev: 0.013796 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.215212 StdDev: 0.012319 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.215212 StdDev: 0.012319 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.15471 StdDev: 0.016011 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.191876 StdDev: 0.015335 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.192956 StdDev: 0.01694 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.192308 StdDev: 0.014571 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.194252 StdDev: 0.01547 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.195765 StdDev: 0.014893 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.201167 StdDev: 0.014813 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.181936 StdDev: 0.016202 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.183449 StdDev: 0.016918 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.202247 StdDev: 0.016939 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.188634 StdDev: 0.013271 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.197061 StdDev: 0.014952 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the red, green and blue layers
l, r, f = np.shape(                            read_data(LRG_PALETTES, TRAIN, STYLE, DATA, RGB))
results = find_best_hyperparameters(np.reshape(read_data(LRG_PALETTES, TRAIN, STYLE, DATA, RGB), (r, l * f)), read_data(LRG_PALETTES, TRAIN, STYLE, CATAGORY), "LRG-PALETTES-RGB", "STYLE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.188868 using parametrs: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.141267 StdDev: 0.0011 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.141267 StdDev: 0.0011 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.155854 StdDev: 0.004942 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.155854 StdDev: 0.004942 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.153359 StdDev: 0.00398 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.156046 StdDev: 0.005084 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.155854 StdDev: 0.004942 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.141267 StdDev: 0.0011 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.15643 StdDev: 0.007484 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.156622 StdDev: 0.007136 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.15643 StdDev: 0.007484 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.15643 StdDev: 0.007484 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.164683 StdDev: 0.008153 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.168714 StdDev: 0.006534 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.176583 StdDev: 0.00554 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.176583 StdDev: 0.00554 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.164683 StdDev: 0.005476 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.176583 StdDev: 0.00554 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.176583 StdDev: 0.00554 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.166603 StdDev: 0.007562 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.180038 StdDev: 0.005657 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.18023 StdDev: 0.005708 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.180038 StdDev: 0.005657 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.180038 StdDev: 0.005657 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.166603 StdDev: 0.008402 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.170825 StdDev: 0.008405 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.188676 StdDev: 0.006769 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.188868 StdDev: 0.006785 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.180614 StdDev: 0.005524 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.188484 StdDev: 0.006883 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.188484 StdDev: 0.006944 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.167562 StdDev: 0.008154 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.187524 StdDev: 0.010129 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.181766 StdDev: 0.009079 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.187332 StdDev: 0.010256 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.187524 StdDev: 0.010198 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.135317 StdDev: 0.009002 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.152015 StdDev: 0.009681 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.161036 StdDev: 0.008232 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.16238 StdDev: 0.009135 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.157965 StdDev: 0.009358 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.16334 StdDev: 0.006023 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.166987 StdDev: 0.006585 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.15048 StdDev: 0.007551 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.158157 StdDev: 0.008071 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.164875 StdDev: 0.008158 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.159309 StdDev: 0.007141 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.160653 StdDev: 0.006308 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the hue, luminence and saturation layers
l, r, f = np.shape(                            read_data(LRG_PALETTES, TRAIN, ARTIST, DATA, HLS))
results = find_best_hyperparameters(np.reshape(read_data(LRG_PALETTES, TRAIN, ARTIST, DATA, HLS), (r, l * f)), read_data(LRG_PALETTES, TRAIN, ARTIST, CATAGORY), "LRG-PALETTES-HLS", "ARTIST", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.444685 using parametrs: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.367329 StdDev: 0.006209 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.36236 StdDev: 0.005977 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.407087 StdDev: 0.013372 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.407087 StdDev: 0.013372 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.406655 StdDev: 0.012653 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.407087 StdDev: 0.013372 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.407087 StdDev: 0.013372 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.373596 StdDev: 0.00614 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.411193 StdDev: 0.015655 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.411193 StdDev: 0.015655 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.411193 StdDev: 0.015655 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.411193 StdDev: 0.015655 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.419188 StdDev: 0.017971 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.420484 StdDev: 0.017597 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.420916 StdDev: 0.013723 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.420916 StdDev: 0.013723 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.419836 StdDev: 0.014144 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.420916 StdDev: 0.013723 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.420916 StdDev: 0.013723 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.425454 StdDev: 0.021252 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.444252 StdDev: 0.023523 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.444685 StdDev: 0.023259 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.444252 StdDev: 0.023523 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.444468 StdDev: 0.023198 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.364088 StdDev: 0.022939 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.370787 StdDev: 0.022739 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.39153 StdDev: 0.017002 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.39153 StdDev: 0.016958 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.392826 StdDev: 0.017277 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.391746 StdDev: 0.017018 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.39153 StdDev: 0.017002 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.394555 StdDev: 0.024191 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.419836 StdDev: 0.017434 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.421132 StdDev: 0.016567 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.41962 StdDev: 0.017246 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.419188 StdDev: 0.017471 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.312662 StdDev: 0.026577 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.346586 StdDev: 0.02736 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.352636 StdDev: 0.024814 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.351556 StdDev: 0.024925 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.35242 StdDev: 0.024852 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.353933 StdDev: 0.025162 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.359334 StdDev: 0.022851 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.363872 StdDev: 0.024905 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.373812 StdDev: 0.025496 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.380726 StdDev: 0.022805 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.372731 StdDev: 0.025291 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.382022 StdDev: 0.027982 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the hue, luminence and saturation layers
l, r, f = np.shape(                            read_data(LRG_PALETTES, TRAIN, GENRE, DATA, HLS))
results = find_best_hyperparameters(np.reshape(read_data(LRG_PALETTES, TRAIN, GENRE, DATA, HLS), (r, l * f)), read_data(LRG_PALETTES, TRAIN, GENRE, CATAGORY), "LRG-PALETTES-HLS", "GENRE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.227528 using parametrs: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.213483 StdDev: 0.002806 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.213483 StdDev: 0.002806 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.226448 StdDev: 0.012589 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.226448 StdDev: 0.012589 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.227312 StdDev: 0.01305 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.226448 StdDev: 0.012589 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.226448 StdDev: 0.012589 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.213483 StdDev: 0.002806 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.227528 StdDev: 0.014973 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.227528 StdDev: 0.014973 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.227528 StdDev: 0.014973 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.227312 StdDev: 0.014612 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.218237 StdDev: 0.014431 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.218237 StdDev: 0.014315 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.222342 StdDev: 0.016093 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.222558 StdDev: 0.015872 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.223639 StdDev: 0.015712 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.222342 StdDev: 0.016093 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.222342 StdDev: 0.016093 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.219317 StdDev: 0.014157 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.224071 StdDev: 0.015915 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.224287 StdDev: 0.015729 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.224071 StdDev: 0.015915 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.224071 StdDev: 0.015915 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.191011 StdDev: 0.013955 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.19382 StdDev: 0.012915 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.207217 StdDev: 0.01558 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.206569 StdDev: 0.015588 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.207217 StdDev: 0.01558 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.207217 StdDev: 0.01558 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.207001 StdDev: 0.015532 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.184961 StdDev: 0.013096 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.202679 StdDev: 0.014809 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.202247 StdDev: 0.013739 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.202679 StdDev: 0.014809 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.202895 StdDev: 0.015162 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.14758 StdDev: 0.0128 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.172861 StdDev: 0.018038 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.175454 StdDev: 0.016155 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.176318 StdDev: 0.01619 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.174806 StdDev: 0.017458 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.179343 StdDev: 0.015196 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.1828 StdDev: 0.013475 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.167459 StdDev: 0.016468 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.170916 StdDev: 0.016134 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.179775 StdDev: 0.012705 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.173293 StdDev: 0.016118 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.174373 StdDev: 0.018099 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
# flatten the hue, luminence and saturation layers
l, r, f = np.shape(                            read_data(LRG_PALETTES, TRAIN, STYLE, DATA, HLS))
results = find_best_hyperparameters(np.reshape(read_data(LRG_PALETTES, TRAIN, STYLE, DATA, HLS), (r, l * f)), read_data(LRG_PALETTES,   TRAIN, STYLE,  CATAGORY), "LRG-PALETTES-HLS", "STYLE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.241459 using parametrs: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.20499 StdDev: 0.007014 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.20595 StdDev: 0.006243 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.234357 StdDev: 0.0064 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.234357 StdDev: 0.0064 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.233205 StdDev: 0.005847 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.234357 StdDev: 0.0064 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.234357 StdDev: 0.0064 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.20691 StdDev: 0.007537 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.234741 StdDev: 0.006201 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.234741 StdDev: 0.006201 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.234741 StdDev: 0.006201 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.234741 StdDev: 0.006201 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.239347 StdDev: 0.011455 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.239539 StdDev: 0.011964 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.236084 StdDev: 0.008455 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.236084 StdDev: 0.008455 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.237044 StdDev: 0.006551 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.236084 StdDev: 0.008455 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.236084 StdDev: 0.008455 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.241459 StdDev: 0.011991 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.237044 StdDev: 0.011178 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.236852 StdDev: 0.009892 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.237044 StdDev: 0.011178 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.237044 StdDev: 0.011178 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.205374 StdDev: 0.01478 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.206142 StdDev: 0.014082 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.220729 StdDev: 0.01329 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.220921 StdDev: 0.013303 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.219194 StdDev: 0.013933 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.220729 StdDev: 0.01329 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.220729 StdDev: 0.01329 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.203071 StdDev: 0.016167 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.220154 StdDev: 0.016363 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.224376 StdDev: 0.01191 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.220154 StdDev: 0.016363 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.220154 StdDev: 0.016363 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.162188 StdDev: 0.012569 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.192514 StdDev: 0.01465 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.197121 StdDev: 0.013346 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.198081 StdDev: 0.013172 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.197121 StdDev: 0.012553 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.198081 StdDev: 0.013374 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.200384 StdDev: 0.013492 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.184069 StdDev: 0.018151 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.18906 StdDev: 0.016113 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.198273 StdDev: 0.013919 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.191555 StdDev: 0.015329 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.19405 StdDev: 0.013961 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
results = find_best_hyperparameters(read_data(IMAGE, TRAIN, ARTIST, DATA), read_data(IMAGE, TRAIN, ARTIST, CATAGORY), "IMAGE", "ARTIST", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.809421 using parametrs: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.445765 StdDev: 0.011983 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.445765 StdDev: 0.011983 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.451815 StdDev: 0.013695 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.445765 StdDev: 0.011983 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.445765 StdDev: 0.011983 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.353068 StdDev: 0.002541 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.479041 StdDev: 0.01028 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.479257 StdDev: 0.010081 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.479041 StdDev: 0.01028 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.479041 StdDev: 0.01028 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.686474 StdDev: 0.019839 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.686474 StdDev: 0.018267 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.746543 StdDev: 0.015506 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.746543 StdDev: 0.015506 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.747839 StdDev: 0.016578 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.746543 StdDev: 0.015506 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.746543 StdDev: 0.015506 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.684097 StdDev: 0.021716 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.759291 StdDev: 0.014817 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.759291 StdDev: 0.014817 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.759291 StdDev: 0.014817 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.759291 StdDev: 0.014817 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.775065 StdDev: 0.014428 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.785004 StdDev: 0.015265 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.808341 StdDev: 0.011354 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.808341 StdDev: 0.011354 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.80726 StdDev: 0.01232 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.808124 StdDev: 0.011176 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.808124 StdDev: 0.011176 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.77701 StdDev: 0.015038 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.807476 StdDev: 0.011273 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.807476 StdDev: 0.011273 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.807476 StdDev: 0.011273 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.807476 StdDev: 0.011273 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.765341 StdDev: 0.011332 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.79624 StdDev: 0.010053 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.804667 StdDev: 0.00945 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.804235 StdDev: 0.00915 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.805748 StdDev: 0.010483 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.804019 StdDev: 0.009219 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.805748 StdDev: 0.010398 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.794944 StdDev: 0.011234 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.809421 StdDev: 0.009978 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.806612 StdDev: 0.008616 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.808989 StdDev: 0.009755 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.808341 StdDev: 0.011374 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
results = find_best_hyperparameters(read_data(IMAGE, TRAIN, GENRE, DATA), read_data(IMAGE, TRAIN, GENRE, CATAGORY), "IMAGE", "GENRE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.576707 using parametrs: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.213483 StdDev: 0.002806 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.212619 StdDev: 0.003087 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.341832 StdDev: 0.011801 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.341832 StdDev: 0.011801 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.350259 StdDev: 0.013328 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.341832 StdDev: 0.011801 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.341832 StdDev: 0.011801 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.212835 StdDev: 0.002581 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.35242 StdDev: 0.013407 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.35242 StdDev: 0.013407 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.35242 StdDev: 0.013407 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.35242 StdDev: 0.013407 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.488548 StdDev: 0.01577 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.490277 StdDev: 0.013547 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.534572 StdDev: 0.012031 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.534572 StdDev: 0.012031 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.535436 StdDev: 0.011655 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.534572 StdDev: 0.012031 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.534572 StdDev: 0.012031 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.488116 StdDev: 0.018247 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.539974 StdDev: 0.01336 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.539974 StdDev: 0.01336 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.539974 StdDev: 0.01336 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.539974 StdDev: 0.01336 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.538894 StdDev: 0.015216 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.548617 StdDev: 0.015119 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.575843 StdDev: 0.011782 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.575843 StdDev: 0.011782 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.576707 StdDev: 0.011451 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.576059 StdDev: 0.011933 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.575843 StdDev: 0.011782 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.537165 StdDev: 0.019294 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.568712 StdDev: 0.014266 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.567848 StdDev: 0.015262 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.568712 StdDev: 0.014266 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.568712 StdDev: 0.014266 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.513181 StdDev: 0.018845 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.549265 StdDev: 0.012392 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.554883 StdDev: 0.016655 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.555315 StdDev: 0.016828 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.557044 StdDev: 0.016603 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.554235 StdDev: 0.016383 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.557692 StdDev: 0.016722 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.550346 StdDev: 0.017874 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.55618 StdDev: 0.01762 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.551858 StdDev: 0.018251 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.554883 StdDev: 0.017742 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.555099 StdDev: 0.018409 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %%
results = find_best_hyperparameters(read_data(IMAGE, TRAIN, STYLE, DATA), read_data(IMAGE, TRAIN, STYLE, CATAGORY), "IMAGE", "STYLE", results)
# Out:
# ------------------------------------------------------------------------------------------
# Best score: 0.513052 using parametrs: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# ------------------------------------------------------------------------------------------
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.144146 StdDev: 0.007849 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.144146 StdDev: 0.007849 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.330326 StdDev: 0.013644 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.330326 StdDev: 0.013644 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.339155 StdDev: 0.012422 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.330326 StdDev: 0.013644 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.330326 StdDev: 0.013644 using: {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.148369 StdDev: 0.014253 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.349328 StdDev: 0.010381 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.349328 StdDev: 0.010381 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.349328 StdDev: 0.010381 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.349328 StdDev: 0.010381 using: {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.46238 StdDev: 0.017554 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.461996 StdDev: 0.017531 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.498656 StdDev: 0.014875 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.498656 StdDev: 0.014875 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.499424 StdDev: 0.016006 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.498848 StdDev: 0.015213 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.498656 StdDev: 0.014875 using: {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.456622 StdDev: 0.016383 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.50096 StdDev: 0.019344 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.501152 StdDev: 0.019361 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.501152 StdDev: 0.019361 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.50096 StdDev: 0.019344 using: {'C': 1.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.478503 StdDev: 0.028209 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.486372 StdDev: 0.026811 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.512476 StdDev: 0.022863 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.512476 StdDev: 0.022863 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.513052 StdDev: 0.023658 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.512476 StdDev: 0.022863 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.512476 StdDev: 0.022863 using: {'C': 10.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.474472 StdDev: 0.024596 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.504607 StdDev: 0.022213 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.504415 StdDev: 0.021647 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.504607 StdDev: 0.022213 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.504607 StdDev: 0.022213 using: {'C': 10.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.460077 StdDev: 0.031026 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.481958 StdDev: 0.025666 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.490211 StdDev: 0.022369 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.490403 StdDev: 0.022348 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.490019 StdDev: 0.022806 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.490787 StdDev: 0.022399 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.490979 StdDev: 0.022002 using: {'C': 100.0, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'saga'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'newton-cg'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'liblinear'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'sag'}
# Mean: 0.485797 StdDev: 0.021686 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l1', 'solver': 'saga'}
# Mean: 0.491555 StdDev: 0.021607 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'newton-cg'}
# Mean: 0.490787 StdDev: 0.022483 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# Mean: 0.0 StdDev: 0.0 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'liblinear'}
# Mean: 0.490211 StdDev: 0.023474 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'sag'}
# Mean: 0.491363 StdDev: 0.021503 using: {'C': 100.0, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'saga'}
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## View the table of best results.
# With all the tests completed we can now view the combined best results.

# %%
results
# Out:
#             classifier             group  \
# 0   LogisticRegression           COLOURS
# 1   LogisticRegression           COLOURS
# 2   LogisticRegression           COLOURS
# 3   LogisticRegression      PALETTES-RGB
# 4   LogisticRegression      PALETTES-RGB
# 5   LogisticRegression      PALETTES-RGB
# 6   LogisticRegression      PALETTES-HLS
# 7   LogisticRegression      PALETTES-HLS
# 8   LogisticRegression      PALETTES-HLS
# 9   LogisticRegression  LRG-PALETTES-RGB
# 10  LogisticRegression  LRG-PALETTES-RGB
# 11  LogisticRegression  LRG-PALETTES-RGB
# 12  LogisticRegression  LRG-PALETTES-HLS
# 13  LogisticRegression  LRG-PALETTES-HLS
# 14  LogisticRegression  LRG-PALETTES-HLS
# 15  LogisticRegression             IMAGE
# 16  LogisticRegression             IMAGE
# 17  LogisticRegression             IMAGE
#
#                                                params     score  target
# 0   {'C': 10.0, 'multi_class': 'multinomial', 'pen...  0.514693  ARTIST
# 1   {'C': 10.0, 'multi_class': 'ovr', 'penalty': '...  0.303587   GENRE
# 2   {'C': 10.0, 'multi_class': 'multinomial', 'pen...  0.304798   STYLE
# 3   {'C': 100.0, 'multi_class': 'multinomial', 'pe...  0.372083  ARTIST
# 4   {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l...  0.213483   GENRE
# 5   {'C': 10.0, 'multi_class': 'ovr', 'penalty': '...  0.186948   STYLE
# 6   {'C': 1.0, 'multi_class': 'multinomial', 'pena...  0.399957  ARTIST
# 7   {'C': 0.1, 'multi_class': 'multinomial', 'pena...  0.229473   GENRE
# 8   {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l...  0.227447   STYLE
# 9   {'C': 10.0, 'multi_class': 'multinomial', 'pen...  0.359551  ARTIST
# 10  {'C': 1.0, 'multi_class': 'ovr', 'penalty': 'l...  0.222990   GENRE
# 11  {'C': 10.0, 'multi_class': 'ovr', 'penalty': '...  0.188868   STYLE
# 12  {'C': 1.0, 'multi_class': 'multinomial', 'pena...  0.444685  ARTIST
# 13  {'C': 0.1, 'multi_class': 'multinomial', 'pena...  0.227528   GENRE
# 14  {'C': 1.0, 'multi_class': 'multinomial', 'pena...  0.241459   STYLE
# 15  {'C': 100.0, 'multi_class': 'multinomial', 'pe...  0.809421  ARTIST
# 16  {'C': 10.0, 'multi_class': 'ovr', 'penalty': '...  0.576707   GENRE
# 17  {'C': 10.0, 'multi_class': 'ovr', 'penalty': '...  0.513052   STYLE

# %% [markdown]
# ## Write the Results to a File
# These are saved into a _.csv_ file to be used later in this section of the project.

# %%
results.to_csv("./data/hyperparameter_results/LogisticRegressionClassifier.csv", index = False)
